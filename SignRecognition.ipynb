# %% [markdown]
# # 1. Import and Install Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
import mediapipe as mp

# Check available attributes in the mediapipe module
print(dir(mp.solutions.holistic))
# Out:
# ['FACEMESH_CONTOURS', 'FACEMESH_TESSELATION', 'HAND_CONNECTIONS', 'HandLandmark', 'Holistic', 'NamedTuple', 'POSE_CONNECTIONS', 'PoseLandmark', 'SolutionBase', '_BINARYPB_FILE_PATH', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_download_oss_pose_landmark_model', 'constant_side_packet_calculator_pb2', 'detections_to_rects_calculator_pb2', 'download_utils', 'gate_calculator_pb2', 'image_to_tensor_calculator_pb2', 'inference_calculator_pb2', 'landmark_projection_calculator_pb2', 'local_file_contents_calculator_pb2', 'non_max_suppression_calculator_pb2', 'np', 'rect_transformation_calculator_pb2', 'roi_tracking_calculator_pb2', 'split_vector_calculator_pb2', 'ssd_anchors_calculator_pb2', 'switch_container_pb2', 'tensors_to_classification_calculator_pb2', 'tensors_to_floats_calculator_pb2', 'tensors_to_landmarks_calculator_pb2']

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)

        # Draw landmarks
        draw_styled_landmarks(image, results)
        image=cv2.flip(image,1)        


        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.right_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
if results.face_landmarks :
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() 

else :
    face= np.zeros(1404)
print(face)
# Out:
# [ 0.6354959   0.54191566 -0.02946014 ...  0.70228857  0.43251655
#   0.0182114 ]

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result_test = extract_keypoints(results)
#
# NameError: name 'results' is not defined

# %%
result_test
# Out:
# array([ 0.63691938,  0.47570074, -0.6611951 , ...,  0.28932324,
#         0.47640961, -0.00814949])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.63691938,  0.47570074, -0.6611951 , ...,  0.28932324,
#         0.47640961, -0.00814949])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_data') 

# Actions that we try to detect
actions = np.array(['Home','I hate you','Which','Stand','White','What','Black'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 1

# %%
# import os
# import numpy as np

# for action in actions: 
#     action_path = os.path.join(DATA_PATH, action)
#     if os.path.exists(action_path):
#         files = os.listdir(action_path)
#         if files:  # Check if the directory is not empty
#             dirmax = np.max(np.array(files).astype(int))
#         else:
#             dirmax = 0  # Set dirmax to 0 if directory is empty
#     else:
#         dirmax = 0  # Set dirmax to 0 if directory doesn't exist
        
#     for sequence in range(1, no_sequences+1):
#         try: 
#             os.makedirs(os.path.join(DATA_PATH, action, str(dirmax + sequence)))
#         except FileExistsError:
#             pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results) 
                image=cv2.flip(image,1)        

                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'Home': 0,
#  'I hate you': 1,
#  'Which': 2,
#  'Stand': 3,
#  'White': 4,
#  'What': 5,
#  'Black': 6}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (210, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (210,)

# %%
X=np.array(sequences)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (11, 7)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, BatchNormalization, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define TensorBoard callback
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
actions.shape[0]
# Out:
# 7

# %%
# model = Sequential()
# model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(sequence_length,1662)))
# model.add(LSTM(128, return_sequences=True, activation='relu'))
# model.add(LSTM(64, return_sequences=False, activation='relu'))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(actions.shape[0], activation='softmax'))
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(sequence_length, 1662)))
model.add(Dropout(0.5))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(Dropout(0.5))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# c:\Users\AIO\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
actions.shape[0]
# Out:
# 7

# %%
# model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from livelossplot.inputs.keras import PlotLossesCallback
plot_loss = PlotLossesCallback()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from livelossplot.inputs.keras import PlotLossesCallback
#       2 plot_loss = PlotLossesCallback()
#
# ModuleNotFoundError: No module named 'livelossplot'

# %%
model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# # Train the model
# history = model.fit(X_train, y_train, epochs=200, batch_size=30,validation_split=0.1, callbacks=[tb_callback, early_stopping])

# # Evaluate the model on test data
# loss, accuracy = model.evaluate(X_test, y_test)
# print("Test Loss:", loss)
# print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 25s 231ms/step - accuracy: 0.1174 - loss: 1.9500
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 229ms/step - accuracy: 0.1992 - loss: 1.9417
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step - accuracy: 0.2751 - loss: 1.9368
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 227ms/step - accuracy: 0.2582 - loss: 1.9238
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.3434 - loss: 1.8766
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 226ms/step - accuracy: 0.3542 - loss: 1.7898
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 224ms/step - accuracy: 0.3991 - loss: 1.7426
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 229ms/step - accuracy: 0.3535 - loss: 1.7625
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - accuracy: 0.4016 - loss: 1.6378
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - accuracy: 0.4010 - loss: 1.5276
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.4267 - loss: 1.5179
# Epoch 12/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.3876 - loss: 1.6252
# Epoch 13/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - accuracy: 0.3903 - loss: 1.4690
# Epoch 14/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.4246 - loss: 1.5002
# Epoch 15/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - accuracy: 0.2897 - loss: 1.9050
# Epoch 16/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - accuracy: 0.4140 - loss: 1.5058
# Epoch 17/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.3645 - loss: 1.6246
# Epoch 18/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 282ms/step - accuracy: 0.4102 - loss: 1.5210
# Epoch 19/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - accuracy: 0.4610 - loss: 1.3860
# Epoch 20/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - accuracy: 0.3848 - loss: 1.4227
# Epoch 21/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - accuracy: 0.4450 - loss: 1.4427
# Epoch 22/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - accuracy: 0.4120 - loss: 1.4658
# Epoch 23/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step - accuracy: 0.4093 - loss: 1.4145
# Epoch 24/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - accuracy: 0.3396 - loss: 1.3971
# Epoch 25/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 282ms/step - accuracy: 0.4436 - loss: 1.4936
# Epoch 26/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 268ms/step - accuracy: 0.3632 - loss: 1.4927
# Epoch 27/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - accuracy: 0.4489 - loss: 1.3327
# Epoch 28/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 292ms/step - accuracy: 0.4451 - loss: 1.3309
# Epoch 29/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 0.4938 - loss: 1.2357
# Epoch 30/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 297ms/step - accuracy: 0.4726 - loss: 1.1742
# Epoch 31/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 303ms/step - accuracy: 0.4881 - loss: 1.2060
# Epoch 32/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step - accuracy: 0.5707 - loss: 1.2447
# Epoch 33/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 287ms/step - accuracy: 0.4618 - loss: 1.3607
# Epoch 34/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - accuracy: 0.4964 - loss: 1.3416
# Epoch 35/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step - accuracy: 0.4154 - loss: 1.3897
# Epoch 36/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - accuracy: 0.4758 - loss: 1.2138
# Epoch 37/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - accuracy: 0.4848 - loss: 1.2506
# Epoch 38/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - accuracy: 0.5332 - loss: 1.2316
# Epoch 39/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 264ms/step - accuracy: 0.5356 - loss: 1.0756
# Epoch 40/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - accuracy: 0.5528 - loss: 0.9767
# Epoch 41/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - accuracy: 0.5948 - loss: 1.0122
# Epoch 42/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 321ms/step - accuracy: 0.5686 - loss: 1.0007
# Epoch 43/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - accuracy: 0.5668 - loss: 0.9508
# Epoch 44/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 273ms/step - accuracy: 0.6767 - loss: 0.8738
# Epoch 45/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - accuracy: 0.4306 - loss: 1.4618
# Epoch 46/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - accuracy: 0.4730 - loss: 1.2707
# Epoch 47/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - accuracy: 0.4995 - loss: 1.2181
# Epoch 48/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.5939 - loss: 1.0432
# Epoch 49/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.6253 - loss: 0.8878
# Epoch 50/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 263ms/step - accuracy: 0.6350 - loss: 0.8554
# Epoch 51/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.6706 - loss: 0.8313
# Epoch 52/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - accuracy: 0.5634 - loss: 0.9642
# Epoch 53/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - accuracy: 0.5603 - loss: 0.9392
# Epoch 54/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - accuracy: 0.6316 - loss: 0.7947
# Epoch 55/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 275ms/step - accuracy: 0.6883 - loss: 0.7981
# Epoch 56/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.6201 - loss: 0.8600
# Epoch 57/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - accuracy: 0.5904 - loss: 0.9286
# Epoch 58/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - accuracy: 0.6548 - loss: 0.8737
# Epoch 59/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - accuracy: 0.6715 - loss: 0.7834
# Epoch 60/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - accuracy: 0.6030 - loss: 0.8511
# Epoch 61/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.6466 - loss: 0.7967
# Epoch 62/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - accuracy: 0.6864 - loss: 0.7952
# Epoch 63/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - accuracy: 0.7002 - loss: 0.7283
# Epoch 64/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 285ms/step - accuracy: 0.6904 - loss: 0.6504
# Epoch 65/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 334ms/step - accuracy: 0.6075 - loss: 0.8779
# Epoch 66/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - accuracy: 0.7485 - loss: 0.6868
# Epoch 67/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 275ms/step - accuracy: 0.6626 - loss: 0.7447
# Epoch 68/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - accuracy: 0.6125 - loss: 0.9035
# Epoch 69/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.6859 - loss: 0.8382
# Epoch 70/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - accuracy: 0.6069 - loss: 0.8755
# Epoch 71/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step - accuracy: 0.6298 - loss: 1.0238
# Epoch 72/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - accuracy: 0.5970 - loss: 0.8784
# Epoch 73/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - accuracy: 0.6656 - loss: 0.7018
# Epoch 74/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step - accuracy: 0.5892 - loss: 0.9058
# Epoch 75/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 281ms/step - accuracy: 0.6793 - loss: 0.8306
# Epoch 76/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.6663 - loss: 0.8619
# Epoch 77/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.7221 - loss: 0.6761
# Epoch 78/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.7883 - loss: 0.5611
# Epoch 79/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.7359 - loss: 0.6636
# Epoch 80/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.7544 - loss: 0.5813
# Epoch 81/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.7953 - loss: 0.5437
# Epoch 82/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - accuracy: 0.7038 - loss: 0.7660
# Epoch 83/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.7282 - loss: 0.6887
# Epoch 84/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.7763 - loss: 0.5433
# Epoch 85/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.7247 - loss: 0.6962
# Epoch 86/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.7869 - loss: 0.6311
# Epoch 87/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.7405 - loss: 0.5502
# Epoch 88/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.7836 - loss: 0.6052
# Epoch 89/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.8053 - loss: 0.4790
# Epoch 90/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - accuracy: 0.7759 - loss: 0.5897
# Epoch 91/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 0.7532 - loss: 0.5609
# Epoch 92/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 316ms/step - accuracy: 0.7941 - loss: 0.4958
# Epoch 93/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 0.7916 - loss: 0.5384
# Epoch 94/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - accuracy: 0.7806 - loss: 0.5329
# Epoch 95/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 297ms/step - accuracy: 0.7707 - loss: 0.5041
# Epoch 96/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 311ms/step - accuracy: 0.8384 - loss: 0.4191
# Epoch 97/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - accuracy: 0.8009 - loss: 0.4919
# Epoch 98/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 406ms/step - accuracy: 0.8178 - loss: 0.3882
# Epoch 99/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 330ms/step - accuracy: 0.7685 - loss: 0.5535
# Epoch 100/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - accuracy: 0.7980 - loss: 0.4395
# Epoch 101/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.8084 - loss: 0.4534
# Epoch 102/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.8050 - loss: 0.4351
# Epoch 103/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 278ms/step - accuracy: 0.7356 - loss: 0.6222
# Epoch 104/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.7808 - loss: 0.5448
# Epoch 105/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - accuracy: 0.6068 - loss: 0.7956
# Epoch 106/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 236ms/step - accuracy: 0.7338 - loss: 0.6908
# Epoch 107/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step - accuracy: 0.7682 - loss: 0.5496
# Epoch 108/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - accuracy: 0.8094 - loss: 0.4796
# Epoch 109/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 363ms/step - accuracy: 0.8329 - loss: 0.4597
# Epoch 110/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - accuracy: 0.8308 - loss: 0.4627
# Epoch 111/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 308ms/step - accuracy: 0.8246 - loss: 0.4419
# Epoch 112/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - accuracy: 0.7648 - loss: 0.5329
# Epoch 113/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.8424 - loss: 0.3832
# Epoch 114/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step - accuracy: 0.7810 - loss: 0.4548
# Epoch 115/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.8614 - loss: 0.3451
# Epoch 116/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step - accuracy: 0.8631 - loss: 0.3713
# Epoch 117/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - accuracy: 0.8420 - loss: 0.4146
# Epoch 118/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - accuracy: 0.8538 - loss: 0.4314
# Epoch 119/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - accuracy: 0.7699 - loss: 0.4772
# Epoch 120/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 278ms/step - accuracy: 0.7385 - loss: 0.7478
# Epoch 121/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 285ms/step - accuracy: 0.7876 - loss: 0.5734
# Epoch 122/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - accuracy: 0.7278 - loss: 0.6618
# Epoch 123/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step - accuracy: 0.8246 - loss: 0.4031
# Epoch 124/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 275ms/step - accuracy: 0.8910 - loss: 0.3555
# Epoch 125/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - accuracy: 0.8746 - loss: 0.3453
# Epoch 126/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step - accuracy: 0.8913 - loss: 0.2539
# Epoch 127/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - accuracy: 0.7898 - loss: 0.4459
# Epoch 128/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - accuracy: 0.8134 - loss: 0.4421
# Epoch 129/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - accuracy: 0.7976 - loss: 0.4056
# Epoch 130/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - accuracy: 0.9078 - loss: 0.2851
# Epoch 131/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - accuracy: 0.8951 - loss: 0.2652
# Epoch 132/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - accuracy: 0.9035 - loss: 0.2891
# Epoch 133/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 293ms/step - accuracy: 0.9093 - loss: 0.2532
# Epoch 134/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 315ms/step - accuracy: 0.8127 - loss: 0.6182
# Epoch 135/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - accuracy: 0.7552 - loss: 0.6203
# Epoch 136/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 312ms/step - accuracy: 0.6956 - loss: 0.9189
# Epoch 137/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - accuracy: 0.6911 - loss: 0.7498
# Epoch 138/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 325ms/step - accuracy: 0.7321 - loss: 0.7266
# Epoch 139/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 297ms/step - accuracy: 0.8259 - loss: 0.4562
# Epoch 140/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 304ms/step - accuracy: 0.8259 - loss: 0.4136
# Epoch 141/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step - accuracy: 0.8400 - loss: 0.4025
# Epoch 142/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 292ms/step - accuracy: 0.8530 - loss: 0.3671
# Epoch 143/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step - accuracy: 0.8632 - loss: 0.4204
# Epoch 144/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - accuracy: 0.8556 - loss: 0.3263
# Epoch 145/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - accuracy: 0.8636 - loss: 0.3763
# Epoch 146/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 297ms/step - accuracy: 0.8757 - loss: 0.3779
# Epoch 147/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - accuracy: 0.8311 - loss: 0.4109
# Epoch 148/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 285ms/step - accuracy: 0.8300 - loss: 0.4062
# Epoch 149/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step - accuracy: 0.8470 - loss: 0.3192
# Epoch 150/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - accuracy: 0.8613 - loss: 0.3115
# Epoch 151/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - accuracy: 0.8698 - loss: 0.3495
# Epoch 152/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - accuracy: 0.9185 - loss: 0.2153
# Epoch 153/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 336ms/step - accuracy: 0.8995 - loss: 0.2958
# Epoch 154/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 330ms/step - accuracy: 0.9162 - loss: 0.2022
# Epoch 155/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.8766 - loss: 0.2719
# Epoch 156/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.9117 - loss: 0.2954
# Epoch 157/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 403ms/step - accuracy: 0.8799 - loss: 0.3190
# Epoch 158/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 433ms/step - accuracy: 0.8059 - loss: 0.5886
# Epoch 159/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 420ms/step - accuracy: 0.8890 - loss: 0.3274
# Epoch 160/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 444ms/step - accuracy: 0.8527 - loss: 0.3737
# Epoch 161/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 375ms/step - accuracy: 0.9152 - loss: 0.2480
# Epoch 162/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 403ms/step - accuracy: 0.9245 - loss: 0.2468
# Epoch 163/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - accuracy: 0.9242 - loss: 0.2164
# Epoch 164/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.8929 - loss: 0.3103
# Epoch 165/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - accuracy: 0.8533 - loss: 0.3971
# Epoch 166/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - accuracy: 0.9110 - loss: 0.2759
# Epoch 167/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - accuracy: 0.9328 - loss: 0.2356
# Epoch 168/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - accuracy: 0.8892 - loss: 0.2464
# Epoch 169/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 388ms/step - accuracy: 0.9011 - loss: 0.2865
# Epoch 170/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - accuracy: 0.8998 - loss: 0.2413
# Epoch 171/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.9391 - loss: 0.2278
# Epoch 172/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9342 - loss: 0.1610
# Epoch 173/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - accuracy: 0.9386 - loss: 0.2039
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 290ms/step - accuracy: 0.9523 - loss: 0.1503
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 294ms/step - accuracy: 0.9103 - loss: 0.2092
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step - accuracy: 0.9173 - loss: 0.1865
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - accuracy: 0.9319 - loss: 0.2234
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 341ms/step - accuracy: 0.9121 - loss: 0.2231
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 342ms/step - accuracy: 0.9174 - loss: 0.2592
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - accuracy: 0.9241 - loss: 0.2037
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 292ms/step - accuracy: 0.9221 - loss: 0.1855
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step - accuracy: 0.9448 - loss: 0.1599
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 296ms/step - accuracy: 0.9302 - loss: 0.2363
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 290ms/step - accuracy: 0.9248 - loss: 0.1841
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 281ms/step - accuracy: 0.9009 - loss: 0.2560
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - accuracy: 0.8867 - loss: 0.3494
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 293ms/step - accuracy: 0.8682 - loss: 0.2908
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 306ms/step - accuracy: 0.9237 - loss: 0.1991
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 301ms/step - accuracy: 0.9272 - loss: 0.2244
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 335ms/step - accuracy: 0.9204 - loss: 0.1763
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 314ms/step - accuracy: 0.8949 - loss: 0.2593
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step - accuracy: 0.8199 - loss: 0.5101
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - accuracy: 0.8240 - loss: 0.4892
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - accuracy: 0.8359 - loss: 0.4323
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - accuracy: 0.8307 - loss: 0.3990
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - accuracy: 0.8514 - loss: 0.3974
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 292ms/step - accuracy: 0.8992 - loss: 0.2438
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 0.8759 - loss: 0.2986
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - accuracy: 0.8739 - loss: 0.3430
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 324ms/step - accuracy: 0.9072 - loss: 0.2512

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8182 - loss: 1.4655
# Test Loss: 1.46550452709198
# Test Accuracy: 0.8181818127632141

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 30, 64)         │       442,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 30, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,790,027 (6.83 MB)
#  Trainable params: 596,675 (2.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,193,352 (4.55 MB)

# %% [markdown]
# # 8. Make Predictions

# %%
label_map
# Out:
# {'Home': 0,
#  'I hate you': 1,
#  'Which': 2,
#  'Stand': 3,
#  'White': 4,
#  'What': 5,
#  'Black': 6}

# %%
if len(sequence) == 30:
    res = model.predict(np.expand_dims(sequence, axis=0))[0]
    print(f"Model raw output: {res}")
    print(f"Predicted action: {actions[np.argmax(res)]}")

    predictions.append(np.argmax(res))
    
    if np.max(res) > threshold:
        action_label = actions[np.argmax(res)]
        if len(sentence) > 0: 
            if action_label != sentence[-1]:
                sentence.append(action_label)
        else:
            sentence.append(action_label)

    if len(sentence) > 5:
        sentence = sentence[-5:]

    image = prob_viz(res, actions, image, colors)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 if len(sequence) == 30:
#       2     res = model.predict(np.expand_dims(sequence, axis=0))[0]
#       3     print(f"Model raw output: {res}")
#
# TypeError: object of type 'numpy.int32' has no len()

# %%
res = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'Home'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'Home'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[10,  0],
#         [ 0,  1]],
#
#        [[ 7,  1],
#         [ 1,  2]],
#
#        [[ 9,  0],
#         [ 0,  2]],
#
#        [[ 8,  1],
#         [ 0,  2]],
#
#        [[ 8,  0],
#         [ 1,  2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.8181818181818182

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(18,18))
#       2 plt.imshow(prob_viz(res, actions, image, colors))
#
# NameError: name 'plt' is not defined

# %%
# # 1. New detection variables
# sequence = []
# sentence = []
# predictions = []
# threshold = 0.5

# cap = cv2.VideoCapture(0)
# # Set mediapipe model 
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#     while cap.isOpened():

#         # Read feed
#         ret, frame = cap.read()

#         # Make detections
#         image, results = mediapipe_detection(frame, holistic)
#         print(results)
        
#         # Draw landmarks
#         draw_styled_landmarks(image, results)
#         image=cv2.flip(image,1)        

        
#         # 2. Prediction logic
#         keypoints = extract_keypoints(results)
#         sequence.append(keypoints)
#         sequence = sequence[-30:]
        
#         if len(sequence) == 30:
#             res = model.predict(np.expand_dims(sequence, axis=0))[0]
#             print(actions[np.argmax(res)])
#             predictions.append(np.argmax(res))
            
            
#         #3. Viz logic
#             if np.unique(predictions[-10:])[0]==np.argmax(res): 
#                 if res[np.argmax(res)] > threshold: 
                    
#                     if len(sentence) > 0: 
#                         if actions[np.argmax(res)] != sentence[-1]:
#                             sentence.append(actions[np.argmax(res)])
#                     else:
#                         sentence.append(actions[np.argmax(res)])

#             if len(sentence) > 5: 
#                 sentence = sentence[-5:]

#             # Viz probabilities
#             image = prob_viz(res, actions, image, colors)
            
#         cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
#         cv2.putText(image, ' '.join(sentence), (3,30), 
#                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
#         # Show to screen
#         cv2.imshow('OpenCV Feed', image)

#         # Break gracefully
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break
#     cap.release()
#     cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Black
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 49
#      46         sentence = sentence[-5:]
#      48     # Viz probabilities
# ---> 49     image = prob_viz(res, actions, image, colors)
#      51 cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
#      52 cv2.putText(image, ' '.join(sentence), (3,30),
#      53                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
#
# Cell In[37], line 5, in prob_viz(res, actions, input_frame, colors)
#       3 output_frame = input_frame.copy()
#       4 for num, prob in enumerate(res):
# ----> 5     cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       6     cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       8 return output_frame
#
# IndexError: list index out of range
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import numpy as np
import mediapipe as mp
# Define actions and colors for visualization
colors = [(245, 117, 16), (117, 245, 16), (16, 117, 245), (255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0)]

 

# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)

# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        image = cv2.flip(image, 1)

        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            # 3. Viz logic
            if np.max(res) > threshold: 
                action_label = actions[np.argmax(res)]
                if len(sentence) > 0: 
                    if action_label != sentence[-1]:
                        sentence.append(action_label)
                else:
                    sentence.append(action_label)

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
            
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Stand
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# Black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Stand
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Home
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# I hate you
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# I hate you
